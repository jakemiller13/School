# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /anaconda3/lib/python3.6/site-packages (1.18.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x10b6c4160>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#TearItUpBTS',
#     'url': 'http://twitter.com/search?q=%23TearItUpBTS',
#     'promoted_content': None,
#     'query': '%23TearItUpBTS',
#     'tweet_volume': 2486394},
#    {'name': 'Chelsea',
#     'url': 'http://twitter.com/search?q=Chelsea',
#     'promoted_content': None,
#     'query': 'Chelsea',
#     'tweet_volume': 673014},
#    {'name': '#MCICHE',
#     'url': 'http://twitter.com/search?q=%23MCICHE',
#     'promoted_content': None,
#     'query': '%23MCICHE',
#     'tweet_volume': 278230},
#    {'name': 'Sarri',
#     'url': 'http://twitter.com/search?q=Sarri',
#     'promoted_content': None,
#     'query': 'Sarri',
#     'tweet_volume': 179193},
#    {'name': '#TiyatronunAdıNamoğlu',
#     'url': 'http://twitter.com/search?q=%23TiyatronunAd%C4%B1Namo%C4%9Flu',
#     'promoted_content': None,
#     'query': '%23TiyatronunAd%C4%B1Namo%C4%9Flu',
#     'tweet_volume': 25632},
#    {'name': '#DancingOnIce',
#     'url': 'http://twitter.com/search?q=%23DancingOnIce',
#     'promoted_content': None,
#     'query': '%23DancingOnIce',
#     'tweet_volume': None},
#    {'name': 'Ümit Öztürk',
#     'url': 'http://twitter.com/search?q=%22%C3%9Cmit+%C3%96zt%C3%BCrk%22',
#     'promoted_content': None,
#     'query': '%22%C3%9Cmit+%C3%96zt%C3%BCrk%22',
#     'tweet_volume': 80233},
#    {'name': '#EvrimAntiBilimdir',
#     'url': 'http://twitter.com/search?q=%23EvrimAntiBilimdir',
#     'promoted_content': None,
#     'query': '%23EvrimAntiBilimdir',
#     'tweet_volume': None},
#    {'name': 'Benfica',
#     'url': 'http://twitter.com/search?q=Benfica',
#     'promoted_content': None,
#     'query': 'Benfica',
#     'tweet_volume': 68945},
#    {'name': 'Man City',
#     'url': 'http://twitter.com/search?q=%22Man+City%22',
#     'promoted_content': None,
#     'query': '%22Man+City%22',
#     'tweet_volume': 135664},
#    {'name': 'Aguero',
#     'url': 'http://twitter.com/search?q=Aguero',
#     'promoted_content': None,
#     'query': 'Aguero',
#     'tweet_volume': 126623},
#    {'name': '777casino bonusuhilbet',
#     'url': 'http://twitter.com/search?q=%22777casino+bonusuhilbet%22',
#     'promoted_content': None,
#     'query': '%22777casino+bonusuhilbet%22',
#     'tweet_volume': None},
#    {'name': 'Mike Dean',
#     'url': 'http://twitter.com/search?q=%22Mike+Dean%22',
#     'promoted_content': None,
#     'query': '%22Mike+Dean%22',
#     'tweet_volume': 28679},
#    {'name': 'Manchester City',
#     'url': 'http://twitter.com/search?q=%22Manchester+City%22',
#     'promoted_content': None,
#     'query': '%22Manchester+City%22',
#     'tweet_volume': 73576},
#    {'name': 'Guardiola',
#     'url': 'http://twitter.com/search?q=Guardiola',
#     'promoted_content': None,
#     'query': 'Guardiola',
#     'tweet_volume': 40104},
#    {'name': 'Mark Wood',
#     'url': 'http://twitter.com/search?q=%22Mark+Wood%22',
#     'promoted_content': None,
#     'query': '%22Mark+Wood%22',
#     'tweet_volume': None},
#    {'name': 'Hazard',
#     'url': 'http://twitter.com/search?q=Hazard',
#     'promoted_content': None,
#     'query': 'Hazard',
#     'tweet_volume': 63926},
#    {'name': 'Ahmet Ağaoğlu',
#     'url': 'http://twitter.com/search?q=%22Ahmet+A%C4%9Fao%C4%9Flu%22',
#     'promoted_content': None,
#     'query': '%22Ahmet+A%C4%9Fao%C4%9Flu%22',
#     'tweet_volume': None},
#    {'name': 'Juventude',
#     'url': 'http://twitter.com/search?q=Juventude',
#     'promoted_content': None,
#     'query': 'Juventude',
#     'tweet_volume': None},
#    {'name': 'Eibar',
#     'url': 'http://twitter.com/search?q=Eibar',
#     'promoted_content': None,
#     'query': 'Eibar',
#     'tweet_volume': None},
#    {'name': 'David Luiz',
#     'url': 'http://twitter.com/search?q=%22David+Luiz%22',
#     'promoted_content': None,
#     'query': '%22David+Luiz%22',
#     'tweet_volume': None},
#    {'name': 'Etihad',
#     'url': 'http://twitter.com/search?q=Etihad',
#     'promoted_content': None,
#     'query': 'Etihad',
#     'tweet_volume': 32183},
#    {'name': 'Cinderela',
#     'url': 'http://twitter.com/search?q=Cinderela',
#     'promoted_content': None,
#     'query': 'Cinderela',
#     'tweet_volume': None},
#    {'name': '#GRAMMYs',
#     'url': 'http://twitter.com/search?q=%23GRAMMYs',
#     'promoted_content': None,
#     'query': '%23GRAMMYs',
#     'tweet_volume': 847946},
#    {'name': '#rainbowLGBTQ',
#     'url': 'http://twitter.com/search?q=%23rainbowLGBTQ',
#     'promoted_content': None,
#     'query': '%23rainbowLGBTQ',
#     'tweet_volume': 14104},
#    {'name': '#KeçiörenSeniBekliyorReis',
#     'url': 'http://twitter.com/search?q=%23Ke%C3%A7i%C3%B6renSeniBekliyorReis',
#     'promoted_content': None,
#     'query': '%23Ke%C3%A7i%C3%B6renSeniBekliyorReis',
#     'tweet_volume': None},
#    {'name': '#BAFTA',
#     'url': 'http://twitter.com/search?q=%23BAFTA',
#     'promoted_content': None,
#     'query': '%23BAFTA',
#     'tweet_volume': 21398},
#    {'name': '#SassuoloJuve',
#     'url': 'http://twitter.com/search?q=%23SassuoloJuve',
#     'promoted_content': None,
#     'query': '%23SassuoloJuve',
#     'tweet_volume': 32702},
#    {'name': '#جمهور_الاهلي_لا_يخضع_للمال',
#     'url': 'http://twitter.com/search?q=%23%D8%AC%D9%85%D9%87%D9%88%D8%B1_%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D9%84%D8%A7_%D9%8A%D8%AE%D8%B6%D8%B9_%D9%84%D9%84%D9%85%D8%A7%D9%84',
#     'promoted_content': None,
#     'query': '%23%D8%AC%D9%85%D9%87%D9%88%D8%B1_%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D9%84%D8%A7_%D9%8A%D8%AE%D8%B6%D8%B9_%D9%84%D9%84%D9%85%D8%A7%D9%84',
#     'tweet_volume': 402253},
#    {'name': '#RosesAreRosieDay',
#     'url': 'http://twitter.com/search?q=%23RosesAreRosieDay',
#     'promoted_content': None,
#     'query': '%23RosesAreRosieDay',
#     'tweet_volume': 478006},
#    {'name': '#GSvsTS',
#     'url': 'http://twitter.com/search?q=%23GSvsTS',
#     'promoted_content': None,
#     'query': '%23GSvsTS',
#     'tweet_volume': None},
#    {'name': '#رويه_العلا',
#     'url': 'http://twitter.com/search?q=%23%D8%B1%D9%88%D9%8A%D9%87_%D8%A7%D9%84%D8%B9%D9%84%D8%A7',
#     'promoted_content': None,
#     'query': '%23%D8%B1%D9%88%D9%8A%D9%87_%D8%A7%D9%84%D8%B9%D9%84%D8%A7',
#     'tweet_volume': 56271},
#    {'name': '#GencoEcer',
#     'url': 'http://twitter.com/search?q=%23GencoEcer',
#     'promoted_content': None,
#     'query': '%23GencoEcer',
#     'tweet_volume': None},
#    {'name': '#TheVoiceKids',
#     'url': 'http://twitter.com/search?q=%23TheVoiceKids',
#     'promoted_content': None,
#     'query': '%23TheVoiceKids',
#     'tweet_volume': 51170},
#    {'name': '#ManCity',
#     'url': 'http://twitter.com/search?q=%23ManCity',
#     'promoted_content': None,
#     'query': '%23ManCity',
#     'tweet_volume': 46266},
#    {'name': '#SaldırGALATASARAY',
#     'url': 'http://twitter.com/search?q=%23Sald%C4%B1rGALATASARAY',
#     'promoted_content': None,
#     'query': '%23Sald%C4%B1rGALATASARAY',
#     'tweet_volume': 10982},
#    {'name': '#MontanerEnLaPeña',
#     'url': 'http://twitter.com/search?q=%23MontanerEnLaPe%C3%B1a',
#     'promoted_content': None,
#     'query': '%23MontanerEnLaPe%C3%B1a',
#     'tweet_volume': None},
#    {'name': '#Trabzonspor',
#     'url': 'http://twitter.com/search?q=%23Trabzonspor',
#     'promoted_content': None,
#     'query': '%23Trabzonspor',
#     'tweet_volume': None},
#    {'name': '#DomenicaIn',
#     'url': 'http://twitter.com/search?q=%23DomenicaIn',
#     'promoted_content': None,
#     'query': '%23DomenicaIn',
#     'tweet_volume': 75692},
#    {'name': '#بالجو_هذا_ودي_اقول',
#     'url': 'http://twitter.com/search?q=%23%D8%A8%D8%A7%D9%84%D8%AC%D9%88_%D9%87%D8%B0%D8%A7_%D9%88%D8%AF%D9%8A_%D8%A7%D9%82%D9%88%D9%84',
#     'promoted_content': None,
#     'query': '%23%D8%A8%D8%A7%D9%84%D8%AC%D9%88_%D9%87%D8%B0%D8%A7_%D9%88%D8%AF%D9%8A_%D8%A7%D9%82%D9%88%D9%84',
#     'tweet_volume': 56003},
#    {'name': '#PAOKOLY',
#     'url': 'http://twitter.com/search?q=%23PAOKOLY',
#     'promoted_content': None,
#     'query': '%23PAOKOLY',
#     'tweet_volume': None},
#    {'name': '#EEBAFTAs',
#     'url': 'http://twitter.com/search?q=%23EEBAFTAs',
#     'promoted_content': None,
#     'query': '%23EEBAFTAs',
#     'tweet_volume': 20451},
#    {'name': '#Luizenmoeder',
#     'url': 'http://twitter.com/search?q=%23Luizenmoeder',
#     'promoted_content': None,
#     'query': '%23Luizenmoeder',
#     'tweet_volume': None},
#    {'name': '#ENGvFRA',
#     'url': 'http://twitter.com/search?q=%23ENGvFRA',
#     'promoted_content': None,
#     'query': '%23ENGvFRA',
#     'tweet_volume': 19899},
#    {'name': '#PREMIERxESPN',
#     'url': 'http://twitter.com/search?q=%23PREMIERxESPN',
#     'promoted_content': None,
#     'query': '%23PREMIERxESPN',
#     'tweet_volume': None},
#    {'name': '#مانشستر_سيتي_تشيلسي',
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%A7%D9%86%D8%B4%D8%B3%D8%AA%D8%B1_%D8%B3%D9%8A%D8%AA%D9%8A_%D8%AA%D8%B4%D9%8A%D9%84%D8%B3%D9%8A',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%A7%D9%86%D8%B4%D8%B3%D8%AA%D8%B1_%D8%B3%D9%8A%D8%AA%D9%8A_%D8%AA%D8%B4%D9%8A%D9%84%D8%B3%D9%8A',
#     'tweet_volume': 32923},
#    {'name': '#MilanCagliari',
#     'url': 'http://twitter.com/search?q=%23MilanCagliari',
#     'promoted_content': None,
#     'query': '%23MilanCagliari',
#     'tweet_volume': None},
#    {'name': '#السيتي_تشيلسي',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D9%8A%D8%AA%D9%8A_%D8%AA%D8%B4%D9%8A%D9%84%D8%B3%D9%8A',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%B3%D9%8A%D8%AA%D9%8A_%D8%AA%D8%B4%D9%8A%D9%84%D8%B3%D9%8A',
#     'tweet_volume': 18446},
#    {'name': '#utrpsv',
#     'url': 'http://twitter.com/search?q=%23utrpsv',
#     'promoted_content': None,
#     'query': '%23utrpsv',
#     'tweet_volume': None},
#    {'name': '#ITZY_DEBUT',
#     'url': 'http://twitter.com/search?q=%23ITZY_DEBUT',
#     'promoted_content': None,
#     'query': '%23ITZY_DEBUT',
#     'tweet_volume': 183031}],
#   'as_of': '2019-02-10T19:58:29Z',
#   'created_at': '2019-02-10T19:54:49Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#TearItUpBTS', 'url': 'http://twitter.com/search?q=%23TearItUpBTS', 'promoted_content': None, 'query': '%23TearItUpBTS', 'tweet_volume': 2486394}, {'name': 'Chelsea', 'url': 'http://twitter.com/search?q=Chelsea', 'promoted_content': None, 'query': 'Chelsea', 'tweet_volume': 673014}, {'name': 'Grammys', 'url': 'http://twitter.com/search?q=Grammys', 'promoted_content': None, 'query': 'Grammys', 'tweet_volume': 1628789}, {'name': 'Toonami', 'url': 'http://twitter.com/search?q=Toonami', 'promoted_content': None, 'query': 'Toonami', 'tweet_volume': None}, {'name': 'Elizabeth Warren', 'url': 'http://twitter.com/search?q=%22Elizabeth+Warren%22', 'promoted_content': None, 'query': '%22Elizabeth+Warren%22', 'tweet_volume': 201091}, {'name': '#UFC234', 'url': 'http://twitter.com/search?q=%23UFC234', 'promoted_content': None, 'query': '%23UFC234', 'tweet_volume': 126325}, {'name': 'Utah State', 'url': 'http://twitter.com/search?q=%22Utah+State%22', 'promoted_content': None, 'query': '%22Utah+State%22', 'tweet_volume': None}, {'name': '#SDFleet', 'url': 'http://twitter.com/search?q=%23SDFleet', 'promoted_content': None, 'query': '%23SDFleet', 'tweet_volume': None}, {'name': '#fleet', 'url': 'http://twitter.com/search?q=%23fleet', 'promoted_content': None, 'query': '%23fleet', 'tweet_volume': None}, {'name': '#rainbowLGBTQ', 'url': 'http://twitter.com/search?q=%23rainbowLGBTQ', 'promoted_content': None, 'query': '%23rainbowLGBTQ', 'tweet_volume': 14104}, {'name': 'Sarri', 'url': 'http://twitter.com/search?q=Sarri', 'promoted_content': None, 'query': 'Sarri', 'tweet_volume': 179193}, {'name': 'Man City', 'url': 'http://twitter.com/search?q=%22Man+City%22', 'promoted_content': None, 'query': '%22Man+City%22', 'tweet_volume': 135664}, {'name': 'Aguero', 'url': 'http://twitter.com/search?q=Aguero', 'promoted_content': None, 'query': 'Aguero', 'tweet_volume': 126623}, {'name': 'Mike Dean', 'url': 'http://twitter.com/search?q=%22Mike+Dean%22', 'promoted_content': None, 'query': '%22Mike+Dean%22', 'tweet_volume': 28679}, {'name': 'Jake Allen', 'url': 'http://twitter.com/search?q=%22Jake+Allen%22', 'promoted_content': None, 'query': '%22Jake+Allen%22', 'tweet_volume': None}, {'name': 'Russell Wilson', 'url': 'http://twitter.com/search?q=%22Russell+Wilson%22', 'promoted_content': None, 'query': '%22Russell+Wilson%22', 'tweet_volume': 19855}, {'name': 'First Sunday', 'url': 'http://twitter.com/search?q=%22First+Sunday%22', 'promoted_content': None, 'query': '%22First+Sunday%22', 'tweet_volume': None}, {'name': 'William Byron', 'url': 'http://twitter.com/search?q=%22William+Byron%22', 'promoted_content': None, 'query': '%22William+Byron%22', 'tweet_volume': None}, {'name': 'The College Dropout', 'url': 'http://twitter.com/search?q=%22The+College+Dropout%22', 'promoted_content': None, 'query': '%22The+College+Dropout%22', 'tweet_volume': 18667}, {'name': 'Manchester City', 'url': 'http://twitter.com/search?q=%22Manchester+City%22', 'promoted_content': None, 'query': '%22Manchester+City%22', 'tweet_volume': 73576}, {'name': 'Bob Costas', 'url': 'http://twitter.com/search?q=%22Bob+Costas%22', 'promoted_content': None, 'query': '%22Bob+Costas%22', 'tweet_volume': None}, {'name': 'Pebble Beach', 'url': 'http://twitter.com/search?q=%22Pebble+Beach%22', 'promoted_content': None, 'query': '%22Pebble+Beach%22', 'tweet_volume': None}, {'name': 'Randy Carlyle', 'url': 'http://twitter.com/search?q=%22Randy+Carlyle%22', 'promoted_content': None, 'query': '%22Randy+Carlyle%22', 'tweet_volume': None}, {'name': 'Kaleb Wesson', 'url': 'http://twitter.com/search?q=%22Kaleb+Wesson%22', 'promoted_content': None, 'query': '%22Kaleb+Wesson%22', 'tweet_volume': None}, {'name': 'Romeo Langford', 'url': 'http://twitter.com/search?q=%22Romeo+Langford%22', 'promoted_content': None, 'query': '%22Romeo+Langford%22', 'tweet_volume': None}, {'name': 'Southern Baptist', 'url': 'http://twitter.com/search?q=%22Southern+Baptist%22', 'promoted_content': None, 'query': '%22So ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#TearItUpBTS",
#     "url": "http://twitter.com/search?q=%23TearItUpBTS",
#     "promoted_content": null,
#     "query": "%23TearItUpBTS",
#     "tweet_volume": 2486394
#    },
#    {
#     "name": "Chelsea",
#     "url": "http://twitter.com/search?q=Chelsea",
#     "promoted_content": null,
#     "query": "Chelsea",
#     "tweet_volume": 673014
#    },
#    {
#     "name": "#rainbowLGBTQ",
#     "url": "http://twitter.com/search?q=%23rainbowLGBTQ",
#     "promoted_content": null,
#     "query": "%23rainbowLGBTQ",
#     "tweet_volume": 14104
#    },
#    {
#     "name": "#MCICHE",
#     "url": "http://twitter.com/search?q=%23MCICHE",
#     "promoted_content": null,
#     "query": "%23MCICHE",
#     "tweet_volume": 278230
#    },
#    {
#     "name": "Sarri",
#     "url": "http://twitter.com/search?q=Sarri",
#     "promoted_content": null,
#     "query": "Sarri",
#     "tweet_volume": 179193
#    },
#    {
#     "name": "#EndABadDateIn5Words",
#     "url": "http://twitter.com/search?q=%23EndABadDateIn5Words",
#     "promoted_content": null,
#     "query": "%23EndABadDateIn5Words",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Daytona500",
#     "url": "http://twitter.com/search?q=%23Daytona500",
#     "promoted_content": null,
#     "query": "%23Daytona500",
#     "tweet_volume": 11423
#    },
#    {
#     "name": "Man City",
#     "url": "http://twitter.com/search?q=%22Man+City%22",
#     "promoted_content": null,
#     "query": "%22Man+City%22",
#     "tweet_volume": 135664
#    },
#    {
#     "name": "Aguero",
#     "url": "http://twitter.com/search?q=Aguero",
#     "promoted_content": null,
#     "query": "Aguero",
#     "tweet_volume": 126623
#    },
#    {
#     "name": "Mike Dean",
#     "url": "http://twitter.com/search?q=%22Mike+Dean%22",
#     "promoted_content": null,
#     "query": "%22Mike+Dean%22",
#     "tweet_volume": 28679
#    },
#    {
#     "name": "Jake Allen",
#     "url": "http://twitter.com/search?q=%22Jake+Allen%22",
#     "promoted_content": null,
#     "query": "%22Jake+Allen%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Russell Wilson",
#     "url": "http://twitter.com/search?q=%22Russell+Wilson%22",
#     "promoted_content": null,
#     "query": "%22Russell+Wilson%22",
#     "tweet_volume": 19855
#    },
#    {
#     "name": "First Sunday",
#     "url": "http://twitter.com/search?q=%22First+Sunday%22",
#     "promoted_content": null,
#     "query": "%22First+Sunday%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "William Byron",
#     "url": "http://twitter.com/search?q=%22William+Byron%22",
#     "promoted_content": null,
#     "query": "%22William+Byron%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The College Dropout",
#     "url": "http://twitter.com/search?q=%22The+College+Dropout%22",
#     "promoted_content": null,
#     "query": "%22The+College+Dropout%22",
#     "tweet_volume": 18667
#    },
#    {
#     "name": "Manchester City",
#     "url": "http://twitter.com/search?q=%22Manchester+City%22",
#     "promoted_content": null,
#     "query": "%22Manchester+City%22",
#     "tweet_volume": 73576
#    },
#    {
#     "name": "Bob Costas",
#     "url": "http://twitter.com/search?q=%22Bob+Costas%22",
#     "promoted_content": null,
#     "query": "%22Bob+Costas%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pebble Beach",
#     "url": "http://twitter.com/search?q=%22Pebble+Beach%22",
#     "promoted_content": null,
#     "query": "%22Pebble+Beach%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Randy Carlyle",
#     "url": "http://twitter.com/search?q=%22Randy+Carlyle%22",
#     "promoted_content": null,
#     "query": "%22Randy+Carlyle%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kaleb Wesson",
#     "url": "http://twitter.com/search?q=%22Kaleb+Wesson%22",
#     "promoted_content": null,
#     "query": "%22Kaleb+Wesson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Romeo Langford",
#     "url": "http://twitter.com/search?q=%22Romeo+Langford%22",
#     "promoted_content": null,
#     "query": "%22Romeo+Langford%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Southern Baptist",
#     "url": "http://twitter.com/search?q=%22Southern+Baptist%22",
#     "promoted_content": null,
#     "query": "%22Southern+Baptist%22",
#     "tweet_volume": 25893
#    },
#    {
#     "name": "Hendrick Motorsports",
#     "url": "http://twitter.com/search?q=%22Hendrick+Motorsports%22",
#     "promoted_content": null,
#     "query": "%22Hendrick+Motorsports%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hazard",
#     "url": "http://twitter.com/search?q=Hazard",
#     "promoted_content": null,
#     "query": "Hazard",
#     "tweet_volume": 63926
#    },
#    {
#     "name": "Liz Cheney",
#     "url": "http://twitter.com/search?q=%22Liz+Cheney%22",
#     "promoted_content": null,
#     "query": "%22Liz+Cheney%22",
#     "tweet_volume": 10470
#    },
#    {
#     "name": "Roman Josi",
#     "url": "http://twitter.com/search?q=%22Roman+Josi%22",
#     "promoted_content": null,
#     "query": "%22Roman+Josi%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chad Knaus",
#     "url": "http://twitter.com/search?q=%22Chad+Knaus%22",
#     "promoted_content": null,
#     "query": "%22Chad+Knaus%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Justin Smith",
#     "url": "http://twitter.com/search?q=%22Justin+Smith%22",
#     "promoted_content": null,
#     "query": "%22Justin+Smith%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bob Murray",
#     "url": "http://twitter.com/search?q=%22Bob+Murray%22",
#     "promoted_content": null,
#     "query": "%22Bob+Murray%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kante",
#     "url": "http://twitter.com/search?q=Kante",
#     "promoted_content": null,
#     "query": "Kante",
#     "tweet_volume": 28044
#    },
#    {
#     "name": "#stlblues",
#     "url": "http://twitter.com/search?q=%23stlblues",
#     "promoted_content": null,
#     "query": "%23stlblues",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SundayFunday",
#     "url": "http://twitter.com/search?q=%23SundayFunday",
#     "promoted_content": null,
#     "query": "%23SundayFunday",
#     "tweet_volume": 14645
#    },
#    {
#     "name": "#FakeRomanceFacts",
#     "url": "http://twitter.com/search?q=%23FakeRomanceFacts",
#     "promoted_content": null,
#     "query": "%23FakeRomanceFacts",
#     "tweet_volume": null
#    },
#    {
#     "name": "#STLvsNSH",
#     "url": "http://twitter.com/search?q=%23STLvsNSH",
#     "promoted_content": null,
#     "query": "%23STLvsNSH",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SundayMorning",
#     "url": "http://twitter.com/search?q=%23SundayMorning",
#     "promoted_content": null,
#     "query": "%23SundayMorning",
#     "tweet_volume": 46066
#    },
#    {
#     "name": "#SundayThoughts",
#     "url": "http://twitter.com/search?q=%23SundayThoughts",
#     "promoted_content": null,
#     "query": "%23SundayThoughts",
#     "tweet_volume": 36381
#    },
#    {
#     "name": "#ReadAMansThoughts",
#     "url": "http://twitter.com/search?q=%23ReadAMansThoughts",
#     "promoted_content": null,
#     "query": "%23ReadAMansThoughts",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BAFTA",
#     "url": "http://twitter.com/search?q=%23BAFTA",
#     "promoted_content": null,
#     "query": "%23BAFTA",
#     "tweet_volume": 21398
#    },
#    {
#     "name": "#SundayMotivation",
#     "url": "http://twitter.com/search?q=%23SundayMotivation",
#     "promoted_content": null,
#     "query": "%23SundayMotivation",
#     "tweet_volume": 49539
#    },
#    {
#     "name": "#Grammy2019",
#     "url": "http://twitter.com/search?q=%23Grammy2019",
#     "promoted_content": null,
#     "query": "%23Grammy2019",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ManCity",
#     "url": "http://twitter.com/search?q=%23ManCity",
#     "promoted_content": null,
#     "query": "%23ManCity",
#     "tweet_volume": 46266
#    },
#    {
#     "name": "#ImJustTryingTo",
#     "url": "http://twitter.com/search?q=%23ImJustTryingTo",
#     "promoted_content": null,
#     "query": "%23ImJustTryingTo",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RosesAreRosieDay",
#     "url": "http://twitter.com/search?q=%23RosesAreRosieDay",
#     "promoted_content": null,
#     "query": "%23RosesAreRosieDay",
#     "tweet_volume": 478006
#    },
#    {
#     "name": "#MCFC",
#     "url": "http://twitter.com/search?q=%23MCFC",
#     "promoted_content": null,
#     "query": "%23MCFC",
#     "tweet_volume": 15691
#    },
#    {
#     "name": "#EEBAFTAs",
#     "url": "http://twitter.com/search?q=%23EEBAFTAs",
#     "promoted_content": null,
#     "query": "%23EEBAFTAs",
#     "tweet_volume": 20451
#    },
#    {
#     "name": "#CollegeDropout15",
#     "url": "http://twitter.com/search?q=%23CollegeDropout15",
#     "promoted_content": null,
#     "query": "%23CollegeDropout15",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PremierLeague",
#     "url": "http://twitter.com/search?q=%23PremierLeague",
#     "promoted_content": null,
#     "query": "%23PremierLeague",
#     "tweet_volume": 11866
#    },
#    {
#     "name": "#COYS",
#     "url": "http://twitter.com/search?q=%23COYS",
#     "promoted_content": null,
#     "query": "%23COYS",
#     "tweet_volume": 24651
#    },
#    {
#     "name": "#AMJoy",
#     "url": "http://twitter.com/search?q=%23AMJoy",
#     "promoted_content": null,
#     "query": "%23AMJoy",
#     "tweet_volume": 12718
#    },
#    {
#     "name": "#AmyForAmerica",
#     "url": "http://twitter.com/search?q=%23AmyForAmerica",
#     "promoted_content": null,
#     "query": "%23AmyForAmerica",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2019-02-10T19:58:30Z",
#   "created_at": "2019-02-10T19:54:49Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# Sarri,Cinderela,#DancingOnIce,#GRAMMYs,Chelsea,#rainbowLGBTQ,#EEBAFTAs,#EvrimAntiBilimdir,#TheVoiceKids,Man City,Ahmet Ağaoğlu,#ManCity,#KeçiörenSeniBekliyorReis,#PAOKOLY,#GSvsTS,Ümit Öztürk,Benfica,#Luizenmoeder,David Luiz,#ITZY_DEBUT,#مانشستر_سيتي_تشيلسي,#رويه_العلا,Mike Dean,Etihad,Mark Wood,#BAFTA,#MilanCagliari,777casino bonusuhilbet,#Trabzonspor,#السيتي_تشيلسي,#بالجو_هذا_ودي_اقول,#PREMIERxESPN,Manchester City,Hazard,Juventude,#MCICHE,Eibar,Aguero,#SassuoloJuve,#جمهور_الاهلي_لا_يخضع_للمال,#GencoEcer,#utrpsv,#TiyatronunAdıNamoğlu,#MontanerEnLaPeña,#DomenicaIn,#SaldırGALATASARAY,#ENGvFRA,#RosesAreRosieDay,#TearItUpBTS,Guardiola
# ('----------', 'us')
# Jake Allen,#SundayThoughts,Sarri,Kante,#EndABadDateIn5Words,#SundayMorning,#ImJustTryingTo,Southern Baptist,Roman Josi,Chelsea,#rainbowLGBTQ,#stlblues,#EEBAFTAs,#AMJoy,The College Dropout,#SundayFunday,#STLvsNSH,Man City,Romeo Langford,#ManCity,Bob Costas,#TearItUpBTS,#COYS,#AmyForAmerica,Hendrick Motorsports,Liz Cheney,#SundayMotivation,Russell Wilson,#FakeRomanceFacts,Bob Murray,Mike Dean,#BAFTA,#Grammy2019,#Daytona500,Manchester City,Hazard,Pebble Beach,#MCICHE,First Sunday,#PremierLeague,Aguero,#MCFC,#ReadAMansThoughts,Randy Carlyle,William Byron,Justin Smith,#CollegeDropout15,#RosesAreRosieDay,Kaleb Wesson,Chad Knaus
# ('----------', 'san diego')
# Jake Allen,#SundayThoughts,Sarri,Kaleb Wesson,#EndABadDateIn5Words,#SundayMorning,#ImJustTryingTo,Southern Baptist,Elizabeth Warren,Chelsea,#rainbowLGBTQ,Roman Josi,#stlblues,#EEBAFTAs,Grammys,The College Dropout,#SundayFunday,#STLvsNSH,Man City,Romeo Langford,#ManCity,Bob Costas,#TearItUpBTS,Hendrick Motorsports,Liz Cheney,#SundayMotivation,#UFC234,Russell Wilson,#FakeRomanceFacts,Mike Dean,#fleet,#BAFTA,Toonami,#Grammy2019,#Daytona500,Manchester City,Hazard,Pebble Beach,#MCICHE,First Sunday,Aguero,#MCFC,#ReadAMansThoughts,Randy Carlyle,William Byron,Justin Smith,#SDFleet,#RosesAreRosieDay,Utah State,Chad Knaus

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#MCICHE', 'Man City', 'Mike Dean', 'Sarri', '#ManCity', '#BAFTA', 'Aguero', 'Chelsea', '#rainbowLGBTQ', '#RosesAreRosieDay', '#EEBAFTAs', '#TearItUpBTS', 'Manchester City', 'Hazard'}
# ('==========', 'intersection of us and san-diego')
# {'Jake Allen', '#SundayThoughts', 'Sarri', 'Kaleb Wesson', '#EndABadDateIn5Words', '#SundayMorning', '#ImJustTryingTo', 'Southern Baptist', 'Roman Josi', 'Chelsea', '#rainbowLGBTQ', '#EEBAFTAs', '#stlblues', 'The College Dropout', '#SundayFunday', '#STLvsNSH', 'Man City', 'Romeo Langford', '#ManCity', 'Bob Costas', 'Hendrick Motorsports', 'Liz Cheney', '#SundayMotivation', 'Russell Wilson', '#FakeRomanceFacts', 'Mike Dean', '#BAFTA', '#Grammy2019', '#Daytona500', 'Manchester City', 'Hazard', 'Pebble Beach', '#MCICHE', 'First Sunday', 'Aguero', '#MCFC', '#ReadAMansThoughts', 'Randy Carlyle', 'William Byron', 'Justin Smith', '#RosesAreRosieDay', '#TearItUpBTS', 'Chad Knaus'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#EndABadDateIn5Words' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
print(len(statuses))
print(statuses)
# Out:
# 100
# [{'created_at': 'Sun Feb 10 20:08:37 +0000 2019', 'id': 1094689616869933058, 'id_str': '1094689616869933058', 'text': "#EndABadDateIn5Words Fuck this shit, I'm out!", 'truncated': False, 'entities': {'hashtags': [{'text': 'EndABadDateIn5Words', 'indices': [0, 20]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 36063391, 'id_str': '36063391', 'name': 'Heather 🍏🔫♐️🏳️\u200d🌈', 'screen_name': 'TheSaxyOne', 'location': 'West Virginia, USA', 'description': "@FreakyRabe's favorite jackass! Pamela Rabe|Wynonna Earp #Earper #Wayhaught|Header by @OliviaJTaylor20|Parlo un po' italiano|Parlo una mica català", 'url': 'https://t.co/eREHI4gZt5', 'entities': {'url': {'urls': [{'url': 'https://t.co/eREHI4gZt5', 'expanded_url': 'https://curiouscat.me/TheSaxyOne', 'display_url': 'curiouscat.me/TheSaxyOne', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2166, 'friends_count': 2785, 'listed_count': 34, 'created_at': 'Tue Apr 28 13:26:11 +0000 2009', 'favourites_count': 59967, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 63147, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1053151542105260037/lge-mEGN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1053151542105260037/lge-mEGN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/36063391/1537602485', 'profile_link_color': '7FDBB6', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DAECF4', 'profile_text_color': '663B12', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, {'created_at': 'Sun Feb 10 20:08:33 +0000 2019', 'id': 1094689601086644225, 'id_str': '1094689601086644225', 'text': 'RT @bjcreigh: It’s not you, it’s me.  #EndABadDateIn5Words', 'truncated': False, 'entities': {'hashtags': [{'text': 'EndABadDateIn5Words', 'indices': [38, 58]}], 'symbols': [], 'user_mentions': [{'screen_name': 'bjcreigh', 'name': 'BallsOut', 'id': 762484767275089920, 'id_str': '762484767275089920', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 51613029, 'id_str': '51613029', 'name': 'satoshi', 'screen_name': 'keepupwitDAjons', 'location': 'hend, nv', 'description': 'ima big retweeter...everything has already been said.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2091, 'friends_count': 3442, 'listed_count': 11, 'created_at': 'Sun Jun 28 01:24:24 +0000 2009', 'favourites_count': 6699, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 28647, 'lang': 'en', 'contributors_enabled': False, 'is_tra ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 81

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ["#EndABadDateIn5Words Fuck this shit, I'm out!",
#  'RT @bjcreigh: It’s not you, it’s me.  #EndABadDateIn5Words',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  '#EndABadDateIn5Words Where can I drop you?',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  'I can’t see you again.  #EndABadDateIn5Words',
#  'RT @Irrmag: "Hope you don\'t mind IBS." #EndABadDateIn5Words',
#  'Total number of  illegal immigrants? \n\n#EndABadDateIn5Words',
#  "I'll pay your bus fare.. #endabaddatein5words",
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  'RT @FuctupMike: I voted for Donald Trump \n#EndABadDateIn5Words',
#  "Oops, I forgot I'm married. #EndABadDateIn5Words",
#  'RT @bigmouth: #EndABadDateIn5Words https://t.co/UnvHfeoRPW',
#  "She might be joining us.                                          \nShe won't be joining us.… https://t.co/m9eo59BNGU",
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  '#EndABadDateIn5Words my dick tiny as shit!!!!!!!!!',
#  '#EndABadDateIn5Words\nSorry, we’re just not compatible 🤷🏾\u200d♀️',
#  '#EndABadDateIn5Words Next date? Twice as fun!',
#  'Do the math on AOC.  #EndABadDateIn5Words',
#  'RT @EmpathyWines: You don’t have Empathy Rosé #EndABadDateIn5Words',
#  '#EndABadDateIn5Words  you remind me of trump https://t.co/kaoGXSfoss',
#  '#EndABadDateIn5Words\nThis date... https://t.co/sdArAYQQqc',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  'I think I am ovulating! #endabaddatein5words',
#  '#EndABadDateIn5Words A geographic concentration of Amerikkkans',
#  'RT @FuctupMike: I voted for Donald Trump \n#EndABadDateIn5Words',
#  'RT @CarbonOrchestra: "We are a zero-sum game" #EndABadDateIn5Words #Hannigram https://t.co/Bku6Ix5r9y',
#  'My Valtrex prescription is ready----\n#EndABadDateIn5Words',
#  'RT @PatrickRandall: #EndABadDateIn5Words   "I\'ve got #Manafort family values!"\n\n(to appreciate this you\'ll need to google "Manafort Family…',
#  '#EndABadDateIn5Words I am going to vomit. https://t.co/vLKpY2Bg46',
#  'I thought you were normal.  #EndABadDateIn5Words',
#  '"I am three months pregnant."\n#EndABadDateIn5Words',
#  '"Go away, you giant weirdo"  #EndABadDateIn5Words',
#  'Gotta polish my skull collection. #EndABadDateIn5Words',
#  "Well, let's just part ways #EndABadDateIn5Words",
#  'RT @FuctupMike: I voted for Donald Trump \n#EndABadDateIn5Words',
#  'Scream “Last one outa here pays” then run #EndABadDateIn5Words',
#  '#EndABadDateIn5Words  I am going to barf!! https://t.co/cqwof8cbhR',
#  '#EndABadDateIn5Words I want 6 kids! #amquerying',
#  'You are trending on Twitter #EndABadDateIn5Words',
#  'Does lithium mix with cocktails? #endabaddatein5words',
#  "Oh, shit, you're a Feminist?  #EndABadDateIn5Words",
#  "#EndABadDateIn5Words I'm ready for marriage &amp; kids! #amquerying",
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  '#EndABadDateIn5Words Are you into open relationships?',
#  'RT @InnovaDiscs: Let me explain flight numbers. 🤓 #EndABadDateIn5Words',
#  'RT @doctorcherokee: SWEETHEART, GREEN NEW DEAL SUCKS.\n#EndABadDateIn5Words',
#  'RT @bigmouth: #EndABadDateIn5Words https://t.co/UnvHfeoRPW',
#  '"Um, yeah. It\'s time to go."\n#EndABadDateIn5Words',
#  '#EndABadDateIn5Words my last date died #amquerying https://t.co/G84GvAxFXM',
#  'You never saw me here... #EndABadDateIn5Words https://t.co/Xyo1r3xliV',
#  "#EndABadDateIn5Words \nIt's not me. It's you. https://t.co/6XP5dGQcg5",
#  'My stepdaughter is REALLY hot.. #endabaddatein5words',
#  'excusey, Thats my safety call !\n #EndABadDateIn5Words',
#  'I currently live my mother\n#EndABadDateIn5Words',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  'RT @PatrickRandall: #EndABadDateIn5Words   "I\'ve got #Manafort family values!"\n\n(to appreciate this you\'ll need to google "Manafort Family…',
#  'Get your fat pants ready...\n#EndABadDateIn5Words https://t.co/iJhkY2SQ0P',
#  "RT @Cattereia: #EndABadDateIn5Words\nIt's over. I give up. https://t.co/9YYKKvabfq",
#  'RT @FuctupMike: I voted for Donald Trump \n#EndABadDateIn5Words',
#  "I want to have 5 kids. It's not 5 words but guaranteed to make him run for the hills.  #EndABadDateIn5Words",
#  'Don’t order the cornbread, fluffy.\n\n#EndABadDateIn5Words https://t.co/wv0Io0nvCk',
#  "Well you're gonna die alone #EndABadDateIn5Words",
#  '#EndABadDateIn5Words \n\nMy home planet needs me!',
#  'I love your camel toe.. #endabaddatein5words',
#  'RT @bigmouth: #EndABadDateIn5Words https://t.co/UnvHfeoRPW',
#  '"By the way, I\'m married." #EndABadDateIn5Words',
#  '#EndABadDateIn5Words   "I\'ve got #Manafort family values!"\n\n(to appreciate this you\'ll need to google "Manafort Fam… https://t.co/9S2GFaFhdM',
#  '#EndABadDateIn5Words I said stop raping me.',
#  'Sorry the wife just called. #EndABadDateIn5Words',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  '#EndABadDateIn5Words Wanna know how I killed my ex?',
#  'See you on #ExOnTheBeach soon #EndABadDateIn5Words',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  '@Joshstrangehill #EndABadDateIn5Words "I have to go now" https://t.co/UiUKYtEzC4',
#  'Kiss me you ugly thing.. #EndABadDateIn5Words',
#  "Can't say it wasn't real. #EndABadDateIn5Words",
#  'Thank you, but no thanks! #EndABadDateIn5Words - https://t.co/PmEjHeop3y',
#  'RT @Fieldsandcows: Talk about your imaginary friend. #EndABadDateIn5Words',
#  'RT @geoffreyclark37: Want to meet my wife #EndABadDateIn5Words',
#  '@RawStory @Exasper8ed #EndABadDateIn5Words \n\nI don’t wash my hands',
#  'RT @EnduringWinter: #EndABadDateIn5Words That’s easy! “We have zero potential, bye!” 🤣💀',
#  "Shouldn't you eat more salad? #endabaddatein5words",
#  '“I just love being celibate”. #EndABadDateIn5Words',
#  "Let's just call it even. #EndABadDateIn5Words",
#  "RT @MermaidOnTV: I think I'm going to...\n#EndABadDateIn5Words https://t.co/FUIWGV5QTb",
#  '"I\'m leaving, you big idiot" #EndABadDateIn5Words',
#  'RT @maxedge051: #EndABadDateIn5Words\n\nWha? Get the f*ck out!  😼 👉 https://t.co/71fGfTYx8R',
#  "#EndABadDateIn5Words that's one very dead monkey! https://t.co/CEac6AoGBk",
#  '#EndABadDateIn5Words Just had a wet fart!!! 🍑🤣🤣👍👍',
#  'RT @bigmouth: #EndABadDateIn5Words https://t.co/UnvHfeoRPW',
#  'RT @SeanMODonnell1: #EndABadDateIn5Words \nI just start cursing relentlessly... https://t.co/9qunW2L9HQ',
#  '#EndABadDateIn5Words Ready to meet "Little Richard"?',
#  'False alarm! I only farted!\n\n#EndABadDateIn5Words',
#  'Just disappear out the door #EndABadDateIn5Words',
#  'Excuse me. I must poop. #EndABadDateIn5Words',
#  'In your honor a royal flush #EndABadDateIn5Words #GirlLove @mariejeancote #Grateful #Blessed https://t.co/SKu5tNw31G',
#  'RT @EmpathyWines: You don’t have Empathy Rosé #EndABadDateIn5Words']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sun Feb 10 20:08:37 +0000 2019",
#  "id": 1094689616869933058,
#  "id_str": "1094689616869933058",
#  "text": "#EndABadDateIn5Words Fuck this shit, I'm out!",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "EndABadDateIn5Words",
#     "indices": [
#      0,
#      20
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 36063391,
#   "id_str": "36063391",
#   "name": "Heather \ud83c\udf4f\ud83d\udd2b\u2650\ufe0f\ud83c\udff3\ufe0f\u200d\ud83c\udf08",
#   "screen_name": "TheSaxyOne",
#   "location": "West Virginia, USA",
#   "description": "@FreakyRabe's favorite jackass! Pamela Rabe|Wynonna Earp #Earper #Wayhaught|Header by @OliviaJTaylor20|Parlo un po' italiano|Parlo una mica catal\u00e0",
#   "url": "https://t.co/eREHI4gZt5",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/eREHI4gZt5",
#       "expanded_url": "https://curiouscat.me/TheSaxyOne",
#       "display_url": "curiouscat.me/TheSaxyOne",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 2166,
#   "friends_count": 2785,
#   "listed_count": 34,
#   "created_at": "Tue Apr 28 13:26:11 +0000 2009",
#   "favourites_count": 59967,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 63147,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme2/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme2/bg.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1053151542105260037/lge-mEGN_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1053151542105260037/lge-mEGN_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/36063391/1537602485",
#   "profile_link_color": "7FDBB6",
#   "profile_sidebar_border_color": "FFFFFF",
#   "profile_sidebar_fill_color": "DAECF4",
#   "profile_text_color": "663B12",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 1,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 0
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "#EndABadDateIn5Words Fuck this shit, I'm out!",
#  "RT @bjcreigh: It\u2019s not you, it\u2019s me.  #EndABadDateIn5Words",
#  "RT @EnduringWinter: #EndABadDateIn5Words That\u2019s easy! \u201cWe have zero potential, bye!\u201d \ud83e\udd23\ud83d\udc80",
#  "#EndABadDateIn5Words Where can I drop you?",
#  "I can\u2019t see you again.  #EndABadDateIn5Words"
# ]
# [
#  "bjcreigh",
#  "EnduringWinter",
#  "Irrmag",
#  "FuctupMike",
#  "bigmouth"
# ]
# [
#  "EndABadDateIn5Words",
#  "EndABadDateIn5Words",
#  "EndABadDateIn5Words",
#  "EndABadDateIn5Words",
#  "EndABadDateIn5Words"
# ]
# [
#  "#EndABadDateIn5Words",
#  "Fuck",
#  "this",
#  "shit,",
#  "I'm"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#EndABadDateIn5Words', 74), ('I', 21), ('RT', 16), ('you', 10), ('to', 10), ('my', 8), ('the', 7), ('#endabaddatein5words', 6), ('just', 6), ("I'm", 5)]
#
# [('bjcreigh', 1), ('EnduringWinter', 1), ('Irrmag', 1), ('FuctupMike', 1), ('bigmouth', 1), ('EmpathyWines', 1), ('CarbonOrchestra', 1), ('PatrickRandall', 1), ('InnovaDiscs', 1), ('doctorcherokee', 1)]
#
# [('EndABadDateIn5Words', 74), ('endabaddatein5words', 6), ('amquerying', 3), ('Manafort', 2), ('Hannigram', 1), ('ExOnTheBeach', 1), ('GirlLove', 1), ('Grateful', 1), ('Blessed', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# #EndABadDateIn5Words |     74
# I                    |     21
# RT                   |     16
# you                  |     10
# to                   |     10
# my                   |      8
# the                  |      7
# #endabaddatein5words |      6
# just                 |      6
# I'm                  |      5
#
#     Screen Name      | Count
# ****************************************
# bjcreigh             |      1
# EnduringWinter       |      1
# Irrmag               |      1
# FuctupMike           |      1
# bigmouth             |      1
# EmpathyWines         |      1
# CarbonOrchestra      |      1
# PatrickRandall       |      1
# InnovaDiscs          |      1
# doctorcherokee       |      1
#
#       Hashtag        | Count
# ****************************************
# EndABadDateIn5Words  |     74
# endabaddatein5words  |      6
# amquerying           |      3
# Manafort             |      2
# Hannigram            |      1
# ExOnTheBeach         |      1
# GirlLove             |      1
# Grateful             |      1
# Blessed              |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#   211   |    bigmouth     | RT @bigmouth: #EndABadDateIn5Words https://t.co/Un
#         |                 | vHfeoRPW
#   50    | EnduringWinter  | RT @EnduringWinter: #EndABadDateIn5Words That’s ea
#         |                 | sy! “We have zero potential, bye!” 🤣💀
#   47    | geoffreyclark37 | RT @geoffreyclark37: Want to meet my wife #EndABad
#         |                 | DateIn5Words
#   34    |   FuctupMike    | RT @FuctupMike: I voted for Donald Trump \#EndABad
#         |                 | DateIn5Words
#   24    |   maxedge051    | RT @maxedge051: #EndABadDateIn5Words\\Wha? Get the
#         |                 |  f*ck out!  😼 👉 https://t.co/71fGfTYx8R
#   24    |    Cattereia    | RT @Cattereia: #EndABadDateIn5Words\It's over. I g
#         |                 | ive up. https://t.co/9YYKKvabfq
#   23    |   MermaidOnTV   | RT @MermaidOnTV: I think I'm going to...\#EndABadD
#         |                 | ateIn5Words https://t.co/FUIWGV5QTb
#   15    | SeanMODonnell1  | RT @SeanMODonnell1: #EndABadDateIn5Words \I just s
#         |                 | tart cursing relentlessly... https://t.co/9qunW2L9
#         |                 | HQ
#   13    |  Fieldsandcows  | RT @Fieldsandcows: Talk about your imaginary frien
#         |                 | d. #EndABadDateIn5Words
#    5    | PatrickRandall  | RT @PatrickRandall: #EndABadDateIn5Words   "I've g
#         |                 | ot #Manafort family values!"\\(to appreciate this
#         |                 | you'll need to google "Manafort Family…
